# %%
# Import libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import requests
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline 
sns.set(color_codes=True)

# %%
url1 = 'https://raw.githubusercontent.com/mandy941/Chinese-Product-in-US-Market/main/SNACK%20MARKET/Analysis%20Data/chocolate/Yami%20Chocolate.csv'
url2 = 'https://raw.githubusercontent.com/mandy941/Chinese-Product-in-US-Market/main/SNACK%20MARKET/Analysis%20Data/chocolate/Chocolate%20Data-%20weee%20ScrapeStorm.csv'
url3 = 'https://raw.githubusercontent.com/mandy941/Chinese-Product-in-US-Market/main/SNACK%20MARKET/Analysis%20Data/chocolate/chocolate-freshgogoData-ScrapeStorm.csv'
yami = pd.read_csv(url1, encoding='latin1')
yami.head()
# Out:
#                                 Product_Name        Brand  Price  Reviews  \
# 0  Pocky Almond Chocolate Biscuit Sticks 41g        glico   2.19      290
# 1  Koala Chocolate Cream Filling Biscuit 41g  lotte japan   1.19      142
# 2     Meltyblend Chocolate Premium Cacao 60g        meiji   3.99      135
# 3         Chocolate Flavored Soy Drink 250ml      vitasoy   0.79      238
# 4      Bun With Chocolate Filling Breadd 75g       d-plus   1.99       26
#
#       Origin  Rate Platform   Category  Sold_Weekly  Sold_Monthly  \
# 0      Japan   4.9     Yami  Chocolate          400          1600
# 1      Japan   4.8     Yami  Chocolate          400          1600
# 2      Japan   4.8     Yami  Chocolate          400          1600
# 3  Hong Kong   4.7     Yami  Chocolate          400          1600
# 4      Japan   4.5     Yami  Chocolate          200           800
#
#    Weekly_Revenue
# 0           876.0
# 1           476.0
# 2          1596.0
# 3           316.0
# 4           398.0

# %%
weee = pd.read_csv(url2, encoding='latin1')
weee.head()
# Out:
#                                         Product_Name  Price  Sold_Weekly  \
# 0              Siete Mexican Chocolate Cookie 4.5 oz   4.79            0
# 1            Cal-C-Tose Drink Mix, Chocolate 14.1 oz   4.49            0
# 2  MACARON Chocolate Cookies, Matcha Mousse And C...   2.49           11
# 3  Mini Chocke-Obleas Chocolate Wafers with Choco...  18.99            0
# 4             Franzzi Cheese Chocolate Cookies 126 g   3.59            0
#
#            Origin    Brand  Reviews Platform   Category  Sold_Monthly  \
# 0   United States    SIETE        1     Weee  Chocolate             0
# 1          Mexico  Unclear        0     Weee  Chocolate             0
# 2  Mainland China  Unclear        1     Weee  Chocolate            44
# 3          Mexico  Unclear        0     Weee  Chocolate             0
# 4  Mainland China  FRANZZI        3     Weee  Chocolate             0
#
#    Weekly_Revenue     Rate
# 0               0  Unclear
# 1               0  Unclear
# 2              27  Unclear
# 3               0  Unclear
# 4               0  Unclear

# %%
freshgogo = pd.read_csv(url3)
freshgogo.head()
# Out:
#    Price                                  Product_Name          Origin  \
# 0   2.39       LOTTE Capuccyo Biscuit Choco (doraemon)           Japan
# 1   2.09                         MEIJI Black Chocolate           Japan
# 2   6.99  TASHI Chocolate Gold Coins with Cocoa Butter          Taiwan
# 3   6.99              YA KANG LE Chocolate (Last Call)  Mainland China
# 4   2.49   LAGO Rondo Coconut Cream and Dark Chocolate           Italy
#
#    Sold_Monthly  Reviews    Platform   Category     Rate    Brand  \
# 0          7084        0  Freshogogo  Chocolate  Unclear  Unclear
# 1          2404        0  Freshogogo  Chocolate  Unclear  Unclear
# 2             0        0  Freshogogo  Chocolate  Unclear  Unclear
# 3             0        0  Freshogogo  Chocolate  Unclear  Unclear
# 4             0        1  Freshogogo  Chocolate  Unclear  Unclear
#
#    Sold_Weekly  Weekly_Revenue
# 0         1771            4233
# 1          601            1256
# 2            0               0
# 3            0               0
# 4            0               0

# %% [markdown]
# # Combine three tables together

# %%
chocolate = pd.concat([yami,freshgogo,weee])
chocolate.head()
# Out:
# C:\Users\13750\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#          Brand   Category     Origin Platform  Price  \
# 0        glico  Chocolate      Japan     Yami   2.19
# 1  lotte japan  Chocolate      Japan     Yami   1.19
# 2        meiji  Chocolate      Japan     Yami   3.99
# 3      vitasoy  Chocolate  Hong Kong     Yami   0.79
# 4       d-plus  Chocolate      Japan     Yami   1.99
#
#                                 Product_Name Rate  Reviews  Sold_Monthly  \
# 0  Pocky Almond Chocolate Biscuit Sticks 41g  4.9      290          1600
# 1  Koala Chocolate Cream Filling Biscuit 41g  4.8      142          1600
# 2     Meltyblend Chocolate Premium Cacao 60g  4.8      135          1600
# 3         Chocolate Flavored Soy Drink 250ml  4.7      238          1600
# 4      Bun With Chocolate Filling Breadd 75g  4.5       26           800
#
#    Sold_Weekly  Weekly_Revenue
# 0          400           876.0
# 1          400           476.0
# 2          400          1596.0
# 3          400           316.0
# 4          200           398.0

# %%
print(chocolate.shape)
print(list(chocolate.columns))
# Out:
# (1986, 11)
# ['Brand', 'Category', 'Origin', 'Platform', 'Price', 'Product_Name', 'Rate', 'Reviews', 'Sold_Monthly', 'Sold_Weekly', 'Weekly_Revenue']

# %% [markdown]
# # Analysis

# %%
chocolate.describe()
# Out:
#              Price      Reviews  Sold_Monthly  Sold_Weekly  Weekly_Revenue
# count  1986.000000  1986.000000   1986.000000  1986.000000     1986.000000
# mean      8.737739     9.832830   1408.545317   352.136455     3036.329179
# std      12.096302    29.633245    635.198578   158.799907     4643.419464
# min       0.390000     0.000000      0.000000     0.000000        0.000000
# 25%       2.790000     0.000000   1600.000000   400.000000      796.000000
# 50%       4.500000     2.000000   1600.000000   400.000000     1506.500000
# 75%       9.497500     7.000000   1600.000000   400.000000     3160.000000
# max     175.000000   461.000000   9362.000000  2341.000000    67960.000000

# %% [markdown]
# # Analysis

# %%
chocolate.sum(axis = 0)
# Out:
# Brand             glicolotte japanmeijivitasoyd-plusglicouhaglic...
# Category          ChocolateChocolateChocolateChocolateChocolateC...
# Origin            JapanJapanJapanHong KongJapanJapanJapanJapanTa...
# Platform          YamiYamiYamiYamiYamiYamiYamiYamiYamiYamiYamiYa...
# Price                                                       17353.1
# Product_Name      Pocky Almond Chocolate Biscuit Sticks 41gKoala...
# Reviews                                                       19528
# Sold_Monthly                                                2797371
# Sold_Weekly                                                  699343
# Weekly_Revenue                                          6.03015e+06
# dtype: object

# %%
chocolate['Origin'] = chocolate['Origin'].replace('ROYAL FAMILY','Unclear')

# %% [markdown]
# # The Most Popular Origin (Highest Weekly Revenue /Num of Product)

# %%
origin = chocolate.groupby(['Origin'])['Product_Name'].count()
origin
# Out:
# Origin
# Belgium              5
# Canada              30
# England              1
# Estonia              1
# Finland              1
# France               2
# German               4
# Hong Kong           12
# India                1
# Indonesia           28
# Israel               1
# Italy                6
# Itlay                3
# Japan             1192
# Korea               95
# Mainland China     244
# Malaysia            48
# Mexico               6
# New Zealand          5
# Philippines          9
# Singapore            3
# South Korea         13
# Taiwan             148
# Thailand             3
# Unclear             34
# United States       88
# Vietnam              3
# Name: Product_Name, dtype: int64

# %%
pop_origin = chocolate.groupby(['Origin'])['Weekly_Revenue'].sum()/chocolate.groupby(['Origin'])['Product_Name'].count()
pop_origin
# Out:
# Origin
# Belgium           25542.400000
# Canada             6836.716667
# England            2236.000000
# Estonia            1798.000000
# Finland             450.000000
# France             1035.375000
# German              756.000000
# Hong Kong          1712.333333
# India                50.000000
# Indonesia          1134.107143
# Israel              149.000000
# Italy                 0.000000
# Itlay              1822.666667
# Japan              3390.738255
# Korea              1445.084211
# Mainland China     1910.727459
# Malaysia            960.166667
# Mexico               16.666667
# New Zealand        1996.000000
# Philippines         174.666667
# Singapore          1743.333333
# South Korea         836.692308
# Taiwan             3704.133446
# Thailand           1125.416667
# Unclear            3786.764706
# United States      2584.931818
# Vietnam             956.000000
# dtype: float64

# %%
pop_origin.sort_values(ascending=False).head(10)
# Out:
# Origin
# Belgium           25542.400000
# Canada             6836.716667
# Unclear            3786.764706
# Taiwan             3704.133446
# Japan              3390.738255
# United States      2584.931818
# England            2236.000000
# New Zealand        1996.000000
# Mainland China     1910.727459
# Itlay              1822.666667
# dtype: float64

# %% [markdown]
# # The most popular brand

# %%
pop_brand = chocolate.groupby(['Brand'])['Weekly_Revenue'].sum()/chocolate.groupby(['Brand'])['Product_Name'].count()
pop_brand
# Out:
# Brand
# 11-Jul           638.000000
# 77              1497.000000
# ????????????    5196.000000
# BAUDUCCO         318.000000
# BIMBO            100.000000
#                    ...
# yonsei          1596.000000
# yunjian         3196.000000
# yuraku          2128.666667
# zess             796.000000
# zest nova       1316.000000
# Length: 417, dtype: float64

# %%
pop_brand.sort_values(ascending=False).head(5)
# Out:
# Brand
# message de rose          40800.000000
# bvlgari il cioccolato    37500.000000
# godiva                   31426.666667
# delrey                   28337.500000
# can garden               24000.000000
# dtype: float64

# %% [markdown]
# # The Main Import Origin

# %%
main_origin = chocolate.groupby(['Origin'])['Product_Name'].count()
main_origin
# Out:
# Origin
# Belgium              5
# Canada              30
# England              1
# Estonia              1
# Finland              1
# France               2
# German               4
# Hong Kong           12
# India                1
# Indonesia           28
# Israel               1
# Italy                6
# Itlay                3
# Japan             1192
# Korea               95
# Mainland China     244
# Malaysia            48
# Mexico               6
# New Zealand          5
# Philippines          9
# Singapore            3
# South Korea         13
# Taiwan             148
# Thailand             3
# Unclear             34
# United States       88
# Vietnam              3
# Name: Product_Name, dtype: int64

# %%
main_origin.sort_values(ascending=False).head(5)
# Out:
# Origin
# Japan             1192
# Mainland China     244
# Taiwan             148
# Korea               95
# United States       88
# Name: Product_Name, dtype: int64

# %% [markdown]
# # The most value import Origin

# %%
value_origin = chocolate.groupby(['Origin'])['Weekly_Revenue'].sum()
value_origin
# Out:
# Origin
# Belgium            127712.00
# Canada             205101.50
# England              2236.00
# Estonia              1798.00
# Finland               450.00
# France               2070.75
# German               3024.00
# Hong Kong           20548.00
# India                  50.00
# Indonesia           31755.00
# Israel                149.00
# Italy                   0.00
# Itlay                5468.00
# Japan             4041760.00
# Korea              137283.00
# Mainland China     466217.50
# Malaysia            46088.00
# Mexico                100.00
# New Zealand          9980.00
# Philippines          1572.00
# Singapore            5230.00
# South Korea         10877.00
# Taiwan             548211.75
# Thailand             3376.25
# Unclear            128750.00
# United States      227474.00
# Vietnam              2868.00
# Name: Weekly_Revenue, dtype: float64

# %%
value_origin.sort_values(ascending=False).head(5)
# Out:
# Origin
# Japan             4041760.00
# Taiwan             548211.75
# Mainland China     466217.50
# United States      227474.00
# Canada             205101.50
# Name: Weekly_Revenue, dtype: float64

# %% [markdown]
# # platform offers choice - most

# %%
choice = chocolate.groupby(['Platform'])['Product_Name'].count()
choice
# Out:
# Platform
# Freshogogo      25
# Weee           142
# Yami          1819
# Name: Product_Name, dtype: int64

# %%
value_choice =  chocolate.groupby(['Platform'])['Weekly_Revenue'].sum()/chocolate.groupby(['Platform'])['Product_Name'].count()
value_choice
# Out:
# Platform
# Freshogogo    6726.520000
# Weee           772.098592
# Yami          3162.368747
# dtype: float64

# %% [markdown]
# ## The Number of profuct by origin

# %%
count_origin = chocolate.groupby([chocolate['Origin']])['Product_Name'].count()
count_origin.plot(kind='barh',figsize=(10,5),legend=None, title="The Number of Products by Origin ")

# %%
sum_revenue = chocolate.groupby([chocolate['Origin']])['Weekly_Revenue'].sum()
sum_revenue.plot(kind='barh',figsize=(10,5),legend=None, title="The Weekly Revenue by Origin ")

# %%
count_platform = chocolate.groupby(['Platform'])['Product_Name'].count()
count_platform
# Out:
# Platform
# Freshogogo      25
# Weee           142
# Yami          1819
# Name: Product_Name, dtype: int64

# %%
platform = chocolate.groupby([chocolate['Platform']])['Brand'].count()
platform.plot(kind='barh',figsize=(10,5),legend=None, title="The Number of Products by Platform ")

# %%
# Finding the correlation bewteen the Features.
plt.figure(figsize=(8,5))

corr = chocolate.corr()# plot the heatmap
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, 
            annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True))
plt.title('Figure 5: Correlations')
# Out:
# Text(0.5, 1.0, 'Figure 5: Correlations')

# %% [markdown]
# ## Origin vs Platform

# %%
# Origin vs Platform

plt.rcParams['figure.figsize'] = (10, 6)

# compare the year with Origin with Platform
plt.subplot(121)
sns.countplot(x='Platform',hue= 'Origin', data=chocolate, palette = 'husl')
plt.legend(bbox_to_anchor=(-0.2, 0.5), loc='right', borderaxespad=0)
plt.title('Platform vs. Origin')
# Out:
# Text(0.5, 1.0, 'Platform vs. Origin')

# %%
# check the Origin percentage of Platform
plt.rcParams['figure.figsize'] = (10, 6)
ax= plt.subplot(122)
c2_c = pd.crosstab(chocolate.Platform, chocolate.Origin)
c2_c.div(c2_c .sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, ax=ax)
plt.title('Origin percentage by Platform')
plt.legend(bbox_to_anchor=(-0.2, 1), loc='left', borderaxespad=0)
plt.xlabel('Platform')
plt.xticks(rotation=0)
plt.ylabel('Percentage of Origin')

c2_c
# Out:
# C:\Users\13750\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Unrecognized location 'left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   import sys
# Origin      Belgium  Canada  England  Estonia  Finland  France  German  \
# Platform
# Freshogogo        0       0        0        0        0       0       0
# Weee              0       0        0        1        1       0       0
# Yami              5      30        1        0        0       2       4
#
# Origin      Hong Kong  India  Indonesia  ...  Mexico  New Zealand  \
# Platform                                 ...
# Freshogogo          0      0          0  ...       0            0
# Weee                0      1          5  ...       6            0
# Yami               12      0         23  ...       0            5
#
# Origin      Philippines  Singapore  South Korea  Taiwan  Thailand  Unclear  \
# Platform
# Freshogogo            0          0            0       3         0        8
# Weee                  9          0           13       8         2       15
# Yami                  0          3            0     137         1       11
#
# Origin      United States  Vietnam
# Platform
# Freshogogo              0        0
# Weee                   32        0
# Yami                   56        3
#
# [3 rows x 27 columns]

# %% [markdown]
# ## Origin Vs Sold_Weekly_Group

# %%
chocolate['Sold_Weekly_Group'] = pd.cut(x = chocolate['Sold_Weekly'], 
                                   bins = [0,50,100,200,300,400,500,1000,2000,10000],
                                   labels = ['Less than 50','50+','100+','200+','300+','400+','500+','1000+','2000+'])
chocolate.head()
# Out:
#          Brand   Category     Origin Platform  Price  \
# 0        glico  Chocolate      Japan     Yami   2.19
# 1  lotte japan  Chocolate      Japan     Yami   1.19
# 2        meiji  Chocolate      Japan     Yami   3.99
# 3      vitasoy  Chocolate  Hong Kong     Yami   0.79
# 4       d-plus  Chocolate      Japan     Yami   1.99
#
#                                 Product_Name Rate  Reviews  Sold_Monthly  \
# 0  Pocky Almond Chocolate Biscuit Sticks 41g  4.9      290          1600
# 1  Koala Chocolate Cream Filling Biscuit 41g  4.8      142          1600
# 2     Meltyblend Chocolate Premium Cacao 60g  4.8      135          1600
# 3         Chocolate Flavored Soy Drink 250ml  4.7      238          1600
# 4      Bun With Chocolate Filling Breadd 75g  4.5       26           800
#
#    Sold_Weekly  Weekly_Revenue Sold_Weekly_Group
# 0          400           876.0              300+
# 1          400           476.0              300+
# 2          400          1596.0              300+
# 3          400           316.0              300+
# 4          200           398.0              100+

# %%
# origin vs sold weekly group

plt.rcParams['figure.figsize'] = (20, 6)

# compare the year with Origin with Platform
plt.subplot(121)
sns.countplot(x='Sold_Weekly_Group',hue= 'Origin', data=chocolate, palette = 'husl')
plt.legend(bbox_to_anchor=(-0.2, 0.5), loc='right', borderaxespad=0)
plt.title('Sold_Weekly_Group vs. Origin')
# Out:
# Text(0.5, 1.0, 'Sold_Weekly_Group vs. Origin')

# %%
# origin vs sold weekly group

plt.rcParams['figure.figsize'] = (20, 7)
# check the Origin percentage of Platform
ax= plt.subplot(122)
c2_c = pd.crosstab(chocolate.Sold_Weekly_Group, chocolate.Origin)
c2_c.div(c2_c .sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, ax=ax)
plt.title('Origin percentage by Sold_Weekly_Group')
plt.legend(bbox_to_anchor=(-0.2, 1), loc='left', borderaxespad=0)
plt.xlabel('Sold_Weekly_Group')
plt.xticks(rotation=0)
plt.ylabel('Percentage of Origin')

c2_c
# Out:
# C:\Users\13750\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: MatplotlibDeprecationWarning: Unrecognized location 'left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   if __name__ == '__main__':
# Origin             Belgium  Canada  England  Estonia  Finland  France  German  \
# Sold_Weekly_Group
# Less than 50             0       1        0        0        1       1       0
# 50+                      0       0        0        0        0       0       0
# 100+                     0       0        0        1        0       0       0
# 200+                     0       1        0        0        0       0       0
# 300+                     5      28        1        0        0       1       4
# 400+                     0       0        0        0        0       0       0
# 500+                     0       0        0        0        0       0       0
# 1000+                    0       0        0        0        0       0       0
# 2000+                    0       0        0        0        0       0       0
#
# Origin             Hong Kong  India  Indonesia  ...  Mexico  New Zealand  \
# Sold_Weekly_Group                               ...
# Less than 50               0      1          7  ...       1            0
# 50+                        0      0          0  ...       0            0
# 100+                       0      0          3  ...       0            0
# 200+                       0      0          0  ...       0            0
# 300+                      12      0         18  ...       0            5
# 400+                       0      0          0  ...       0            0
# 500+                       0      0          0  ...       0            0
# 1000+                      0      0          0  ...       0            0
# 2000+                      0      0          0  ...       0            0
#
# Origin             Philippines  Singapore  South Korea  Taiwan  Thailand  \
# Sold_Weekly_Group
# Less than 50                 0          0            3      14         1
# 50+                          1          0            1       0         0
# 100+                         2          1            1      16         0
# 200+                         1          0            2       2         0
# 300+                         0          2            1     109         0
# 400+                         0          0            0       0         0
# 500+                         0          0            1       2         2
# 1000+                        0          0            0       1         0
# 2000+                        0          0            0       0         0
#
# Origin             Unclear  United States  Vietnam
# Sold_Weekly_Group
# Less than 50             0              4        0
# 50+                      1              1        0
# 100+                     0             14        0
# 200+                     0              6        0
# 300+                    11             40        3
# 400+                     1              1        0
# 500+                     4              1        0
# 1000+                    3              0        0
# 2000+                    0              0        0
#
# [9 rows x 26 columns]

# %% [markdown]
# ## Price_Group Vs Origin

# %%
chocolate['Price_Group'] = pd.cut(x = chocolate['Price'], 
                                   bins = [0,2,4,6,8,10,12,14,16,10000],
                                   labels = ['Less than 2','2+','4+','6+','8+','10+','12+','14+','16+'])
chocolate.head()
# Out:
#          Brand   Category     Origin Platform  Price  \
# 0        glico  Chocolate      Japan     Yami   2.19
# 1  lotte japan  Chocolate      Japan     Yami   1.19
# 2        meiji  Chocolate      Japan     Yami   3.99
# 3      vitasoy  Chocolate  Hong Kong     Yami   0.79
# 4       d-plus  Chocolate      Japan     Yami   1.99
#
#                                 Product_Name Rate  Reviews  Sold_Monthly  \
# 0  Pocky Almond Chocolate Biscuit Sticks 41g  4.9      290          1600
# 1  Koala Chocolate Cream Filling Biscuit 41g  4.8      142          1600
# 2     Meltyblend Chocolate Premium Cacao 60g  4.8      135          1600
# 3         Chocolate Flavored Soy Drink 250ml  4.7      238          1600
# 4      Bun With Chocolate Filling Breadd 75g  4.5       26           800
#
#    Sold_Weekly  Weekly_Revenue Sold_Weekly_Group  Price_Group
# 0          400           876.0              300+           2+
# 1          400           476.0              300+  Less than 2
# 2          400          1596.0              300+           2+
# 3          400           316.0              300+  Less than 2
# 4          200           398.0              100+  Less than 2

# %%
# origin vs Price group

plt.rcParams['figure.figsize'] = (20, 6)

# compare the year with Origin with price group
plt.subplot(121)
sns.countplot(x='Origin',hue= 'Price_Group', data=chocolate, palette = 'husl')
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(-0.2, 0.5), loc='right', borderaxespad=0)
plt.title('Price_Group vs. Origin')
# Out:
# Text(0.5, 1.0, 'Price_Group vs. Origin')

# %%
# origin vs sold weekly group

plt.rcParams['figure.figsize'] = (20, 7)

# check the Origin percentage of Platform
ax= plt.subplot(122)
c2_c = pd.crosstab(chocolate.Price_Group, chocolate.Origin)
c2_c.div(c2_c .sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, ax=ax)
plt.title('Origin percentage by Price_Group')
plt.legend(bbox_to_anchor=(-0.2, 1), loc='left', borderaxespad=0)
plt.xlabel('Price_Group')
plt.xticks(rotation=0)
plt.ylabel('Percentage of Origin')

c2_c
# Out:
# C:\Users\13750\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Unrecognized location 'left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   # Remove the CWD from sys.path while we load stuff.
# Origin       Belgium  Canada  England  Estonia  Finland  France  German  \
# Price_Group
# Less than 2        0       2        0        0        0       0       4
# 2+                 0       1        0        0        0       0       0
# 4+                 0       7        1        0        0       1       0
# 6+                 0       1        0        0        0       0       0
# 8+                 0       0        0        1        1       0       0
# 10+                0       4        0        0        0       1       0
# 12+                0       1        0        0        0       0       0
# 14+                0       1        0        0        0       0       0
# 16+                5      13        0        0        0       0       0
#
# Origin       Hong Kong  India  Indonesia  ...  Mexico  New Zealand  \
# Price_Group                               ...
# Less than 2          2      1          9  ...       1            0
# 2+                   5      0          9  ...       1            0
# 4+                   3      0          7  ...       3            5
# 6+                   1      0          2  ...       0            0
# 8+                   0      0          0  ...       0            0
# 10+                  0      0          0  ...       0            0
# 12+                  1      0          0  ...       0            0
# 14+                  0      0          0  ...       0            0
# 16+                  0      0          1  ...       1            0
#
# Origin       Philippines  Singapore  South Korea  Taiwan  Thailand  Unclear  \
# Price_Group
# Less than 2            3          0            2      19         1        2
# 2+                     3          2            3      26         2        6
# 4+                     2          0            5      21         0        5
# 6+                     0          0            2      16         0        2
# 8+                     1          0            0      11         0        4
# 10+                    0          0            0       1         0        3
# 12+                    0          0            0       8         0        1
# 14+                    0          1            1       7         0        2
# 16+                    0          0            0      39         0        9
#
# Origin       United States  Vietnam
# Price_Group
# Less than 2              6        2
# 2+                      21        1
# 4+                      21        0
# 6+                      16        0
# 8+                       7        0
# 10+                      2        0
# 12+                      0        0
# 14+                      1        0
# 16+                     14        0
#
# [9 rows x 27 columns]

# %% [markdown]
# ## Price_Group Vs Sold_Weekly_Group

# %%
plt.rcParams['figure.figsize'] = (20, 5)

# check the Price_Group percentage of Sold_Weekly_Group
ax= plt.subplot(122)
c2_c = pd.crosstab(chocolate.Price_Group, chocolate.Sold_Weekly_Group)
c2_c.div(c2_c .sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, ax=ax)
plt.title('Sold_Weekly_Group percentage by Price_Group')
plt.legend(bbox_to_anchor=(-0.1, 1), loc='left', borderaxespad=0)
plt.xlabel('Price_Group')
plt.xticks(rotation=0)
plt.ylabel('Percentage of Sold_Weekly_Group')

c2_c
# Out:
# C:\Users\13750\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Unrecognized location 'left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
# Sold_Weekly_Group  Less than 50  50+  100+  200+  300+  400+  500+  1000+  \
# Price_Group
# Less than 2                  13    2    20     4   238     0     4      0
# 2+                           42    6    28    19   509     3     6      2
# 4+                           22    4    21    11   292     1     7      3
# 6+                           19    1     7     8   103     0     1      0
# 8+                            9    0     7     2    44     0     0      0
# 10+                           6    0     1     0    37     0     1      0
# 12+                           5    0     4     1    35     0     0      0
# 14+                           4    0     1     0    44     0     0      0
# 16+                          26    5     9    10   257     2     3      2
#
# Sold_Weekly_Group  2000+
# Price_Group
# Less than 2            0
# 2+                     1
# 4+                     0
# 6+                     0
# 8+                     0
# 10+                    0
# 12+                    0
# 14+                    0
# 16+                    0

# %%
# price group vs sold weekly group

plt.rcParams['figure.figsize'] = (20, 4)

# compare the year with price group with sold weekly group
plt.subplot(121)
sns.countplot(x='Price_Group',hue= 'Sold_Weekly_Group', data=chocolate, palette = 'husl')
plt.legend(bbox_to_anchor=(-0.2, 0.5), loc='right', borderaxespad=0)
plt.title('Price_Group vs. Sold_Weekly_Group')
# Out:
# Text(0.5, 1.0, 'Price_Group vs. Sold_Weekly_Group')

# %%
chocolate.to_csv(r'C:\Users\13750\Desktop\Empire Bazaar Group Corp\US chinese product market\SNACK MARKET\Analysis Data\chocolate\chocolate.csv', index = False)
