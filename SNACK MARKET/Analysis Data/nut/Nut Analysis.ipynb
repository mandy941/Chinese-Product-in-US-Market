# %%
# Import libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import requests
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline 
sns.set(color_codes=True)

# %%
url1 = 'https://raw.githubusercontent.com/mandy941/Chinese-Product-in-US-Market/main/SNACK%20MARKET/Analysis%20Data/noodle/Yami%20Noodle.csv'
url2 = 'https://raw.githubusercontent.com/mandy941/Chinese-Product-in-US-Market/main/SNACK%20MARKET/Analysis%20Data/noodle/Noodle%20Data-%20weee%20ScrapeStorm.csv'
url3 = 'https://raw.githubusercontent.com/mandy941/Chinese-Product-in-US-Market/main/SNACK%20MARKET/Analysis%20Data/noodle/noodle-freshgogoData-ScrapeStorm.csv'
yami = pd.read_csv(url1, encoding='latin1')
yami.head()
# Out:
#                        Product_Name        Brand  Reviews  Price  \
# 0             GreeNoodle Plain 100g  gree noodle       41   1.99
# 1  Tom Yum Flavor Noodle 46Cal 380g  noodle zero        0   3.99
# 2     Medium Cut Ramen Noodles 600g  noodle soul        1   3.99
# 3            Knife Cut Noodles 600g  noodle soul        0   3.99
# 4       Thin Cut Ramen Noodles 600g  noodle soul        0   3.99
#
#           Origin  Rate Platform Category  Sold_Weekly  Sold_Monthly  \
# 0          Japan   4.6     Yami   Noodle          400          1600
# 1  United States   3.6     Yami   Noodle          400          1600
# 2        Vietnam   5.0     Yami   Noodle          400          1600
# 3        Vietnam   0.0     Yami   Noodle          400          1600
# 4        Vietnam   0.0     Yami   Noodle          400          1600
#
#    Weekly_Revenue
# 0             796
# 1            1596
# 2            1596
# 3            1596
# 4            1596

# %%
weee = pd.read_csv(url2, encoding='latin1')
weee.head()
# Out:
#                                         Product_Name  Price  Sold_Weekly  \
# 0  Longkow Bean Thread Vermicelli Glass Noodles 4...   3.89          900
# 1                      Guanmiao Sliced Noodles 400 g   3.69          700
# 2                 Wang Fresh Knife Cut Noodle 2.2 lb   5.99          600
# 3          Noodle Garden Shanghai Plain Noodles 4 lb   5.99         1000
# 4           Noodle Garden Lanzhou Ramen Noodles 4 lb   5.99          800
#
#            Origin             Brand  Reviews  Sold_Monthly  Weekly_Revenue  \
# 0  Mainland China           Unclear       81          3600            3501
# 1          Taiwan           Unclear       30          2800            2583
# 2     South Korea        Wang Korea      305          2400            3594
# 3  Mainland China  NG-Noodle Garden      129          4000            5990
# 4  Mainland China       Noodle Zero      100          3200            4792
#
#   Platform Category     Rate
# 0     Weee   Noodle  Unclear
# 1     Weee   Noodle  Unclear
# 2     Weee   Noodle  Unclear
# 3     Weee   Noodle  Unclear
# 4     Weee   Noodle  Unclear

# %%
freshgogo = pd.read_csv(url3)
freshgogo.head()
# Out:
#    Price                                     Product_Name          Origin  \
# 0   2.49                 MARQAIS TWIN Plain Noodle (thin)         Unclear
# 1   4.69     QIN ZONG Shanxi Cold Noodle (premium sesame)  Mainland China
# 2   5.29  SAPPORO ICHIBAN Instant Ramen (original flavor)         Unclear
# 3   4.69       QIN ZONG Shanxi Cold Noodle (hot and sour)         Unclear
# 4   6.79                      HANKOW Sichuan Style Noodle  Mainland China
#
#    Sold_Monthly  Reviews    Brand     Rate   Platform Category  Sold_Weekly  \
# 0         10219       12  Unclear  Unclear  Freshgogo   Noodle         2555
# 1          1660        0  Unclear  Unclear  Freshgogo   Noodle          415
# 2          3052        4  Unclear  Unclear  Freshgogo   Noodle          763
# 3          5805        1  Unclear  Unclear  Freshgogo   Noodle         1451
# 4          7689        2  Unclear  Unclear  Freshgogo   Noodle         1922
#
#    Weekly_Revenue
# 0            6361
# 1            1946
# 2            4036
# 3            6806
# 4           13052

# %% [markdown]
# # Combine three tables together

# %%
df = pd.concat([yami,weee,freshgogo])
df.head()
# Out:
# C:\Users\13750\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#          Brand Category         Origin Platform  Price  \
# 0  gree noodle   Noodle          Japan     Yami   1.99
# 1  noodle zero   Noodle  United States     Yami   3.99
# 2  noodle soul   Noodle        Vietnam     Yami   3.99
# 3  noodle soul   Noodle        Vietnam     Yami   3.99
# 4  noodle soul   Noodle        Vietnam     Yami   3.99
#
#                        Product_Name Rate  Reviews  Sold_Monthly  Sold_Weekly  \
# 0             GreeNoodle Plain 100g  4.6       41          1600          400
# 1  Tom Yum Flavor Noodle 46Cal 380g  3.6        0          1600          400
# 2     Medium Cut Ramen Noodles 600g    5        1          1600          400
# 3            Knife Cut Noodles 600g    0        0          1600          400
# 4       Thin Cut Ramen Noodles 600g    0        0          1600          400
#
#    Weekly_Revenue
# 0             796
# 1            1596
# 2            1596
# 3            1596
# 4            1596

# %%
print(df.shape)
print(list(df.columns))
# Out:
# (2721, 11)
# ['Brand', 'Category', 'Origin', 'Platform', 'Price', 'Product_Name', 'Rate', 'Reviews', 'Sold_Monthly', 'Sold_Weekly', 'Weekly_Revenue']

# %% [markdown]
# # Analysis

# %%
df.describe()
# Out:
#              Price      Reviews  Sold_Monthly  Sold_Weekly  Weekly_Revenue
# count  2721.000000  2721.000000   2721.000000  2721.000000     2721.000000
# mean      5.206784    25.215730   1552.188901   388.051084     2007.140390
# std       9.960978    91.541863    837.816885   209.463407     3658.531006
# min       0.220000     0.000000      0.000000     0.000000        0.000000
# 25%       2.290000     0.000000   1600.000000   400.000000      780.000000
# 50%       3.490000     0.000000   1600.000000   400.000000     1196.000000
# 75%       5.590000    12.000000   1600.000000   400.000000     1996.000000
# max     194.400000  2077.000000  14161.000000  3540.000000    77760.000000

# %%
df.sum(axis = 0)
# Out:
# Brand             gree noodlenoodle zeronoodle soulnoodle soulno...
# Category          NoodleNoodleNoodleNoodleNoodleNoodleNoodleNood...
# Origin            JapanUnited StatesVietnamVietnamVietnamJapanMa...
# Platform          YamiYamiYamiYamiYamiYamiYamiYamiYamiYamiYamiYa...
# Price                                                       14167.7
# Product_Name      GreeNoodle Plain 100gTom Yum Flavor Noodle 46C...
# Reviews                                                       68612
# Sold_Monthly                                                4223506
# Sold_Weekly                                                 1055887
# Weekly_Revenue                                              5461429
# dtype: object

# %%
df['Origin'] = df['Origin'].replace('ROYAL FAMILY','Unclear')

# %% [markdown]
# # The Most Popular Origin (Highest Weekly Revenue /Num of Product)

# %%
origin = df.groupby(['Origin'])['Product_Name'].count()
origin
# Out:
# Origin
# Australia            3
# Canada               1
# England              1
# Hong Kong           22
# India                1
# Indonesia           41
# Japan              463
# Korea              287
# Mainland China    1104
# Malaysia            71
# Philippine          17
# Philippines          5
# Singapore           35
# South Korea         39
# Taiwan             347
# Thailand            34
# Unclear            139
# United States       97
# Vietnam             14
# Name: Product_Name, dtype: int64

# %%
pop_origin = df.groupby(['Origin'])['Weekly_Revenue'].sum()/df.groupby(['Origin'])['Product_Name'].count()
pop_origin
# Out:
# Origin
# Australia          1773.666667
# Canada             1953.000000
# England           10104.000000
# Hong Kong          1308.000000
# India                69.000000
# Indonesia          1207.170732
# Japan              1693.980562
# Korea              1399.411150
# Mainland China     1773.542572
# Malaysia           2012.154930
# Philippine         1753.647059
# Philippines         133.600000
# Singapore          2901.314286
# South Korea         741.820513
# Taiwan             1826.256484
# Thailand           1086.264706
# Unclear            7130.899281
# United States      2500.804124
# Vietnam             967.142857
# dtype: float64

# %%
pop_origin.sort_values(ascending=False).head(15)
# Out:
# Origin
# England           10104.000000
# Unclear            7130.899281
# Singapore          2901.314286
# United States      2500.804124
# Malaysia           2012.154930
# Canada             1953.000000
# Taiwan             1826.256484
# Australia          1773.666667
# Mainland China     1773.542572
# Philippine         1753.647059
# Japan              1693.980562
# Korea              1399.411150
# Hong Kong          1308.000000
# Indonesia          1207.170732
# Thailand           1086.264706
# dtype: float64

# %% [markdown]
# # The most popular brand by unit selling

# %%
pop_brand = df.groupby(['Brand'])['Weekly_Revenue'].sum()/df.groupby(['Brand'])['Product_Name'].count()
pop_brand
# Out:
# Brand
# 25er evil        1518.666667
# ACE               357.000000
# AJI               311.500000
# AKuan             897.000000
# Assi              279.000000
#                     ...
# zhoujunji         676.000000
# zhouyoulieguo    1236.000000
# zhudafu          3196.000000
# zidi potato      1196.000000
# zsxx             1396.000000
# Length: 561, dtype: float64

# %%
pop_brand.sort_values(ascending=False).head(5)
# Out:
# Brand
# dayu        77760.0
# joyoung     63996.0
# roseonly    63600.0
# florasis    19960.0
# narita      10396.0
# dtype: float64

# %% [markdown]
# # The popular brand by revenue

# %%
pop_brand2 = df.groupby(['Brand'])['Weekly_Revenue'].sum()
pop_brand2
# Out:
# Brand
# 25er evil        4556
# ACE               357
# AJI               623
# AKuan             897
# Assi              837
#                  ...
# zhoujunji        1352
# zhouyoulieguo    1236
# zhudafu          3196
# zidi potato      5980
# zsxx             2792
# Name: Weekly_Revenue, Length: 561, dtype: int64

# %%
pop_brand2.sort_values(ascending=False).head(5)
# Out:
# Brand
# Unclear        1275387
# calbee          162123
# dayu            155520
# lay's           118332
# noodle zero      95736
# Name: Weekly_Revenue, dtype: int64

# %% [markdown]
# # The Main Import Origin

# %%
main_origin = df.groupby(['Origin'])['Product_Name'].count()
main_origin
# Out:
# Origin
# Australia            3
# Canada               1
# England              1
# Hong Kong           22
# India                1
# Indonesia           41
# Japan              463
# Korea              287
# Mainland China    1104
# Malaysia            71
# Philippine          17
# Philippines          5
# Singapore           35
# South Korea         39
# Taiwan             347
# Thailand            34
# Unclear            139
# United States       97
# Vietnam             14
# Name: Product_Name, dtype: int64

# %%
main_origin.sort_values(ascending=False).head(5)
# Out:
# Origin
# Mainland China    1104
# Japan              463
# Taiwan             347
# Korea              287
# Unclear            139
# Name: Product_Name, dtype: int64

# %% [markdown]
# # The most value import Origin

# %%
value_origin = df.groupby(['Origin'])['Weekly_Revenue'].sum()
value_origin
# Out:
# Origin
# Australia            5321
# Canada               1953
# England             10104
# Hong Kong           28776
# India                  69
# Indonesia           49494
# Japan              784313
# Korea              401631
# Mainland China    1957991
# Malaysia           142863
# Philippine          29812
# Philippines           668
# Singapore          101546
# South Korea         28931
# Taiwan             633711
# Thailand            36933
# Unclear            991195
# United States      242578
# Vietnam             13540
# Name: Weekly_Revenue, dtype: int64

# %%
value_origin.sort_values(ascending=False).head(5)
# Out:
# Origin
# Mainland China    1957991
# Unclear            991195
# Japan              784313
# Taiwan             633711
# Korea              401631
# Name: Weekly_Revenue, dtype: int64

# %% [markdown]
# # platform offers choice - most

# %%
choice = df.groupby(['Platform'])['Product_Name'].count()
choice
# Out:
# Platform
# Freshgogo     100
# Weee          300
# Yami         2321
# Name: Product_Name, dtype: int64

# %%
value_choice =  df.groupby(['Platform'])['Weekly_Revenue'].sum()/df.groupby(['Platform'])['Product_Name'].count()
value_choice
# Out:
# Platform
# Freshgogo    9346.590000
# Weee         1659.236667
# Yami         1735.889272
# dtype: float64

# %% [markdown]
# ## The Number of profuct by origin

# %%
count_origin = df.groupby([df['Origin']])['Product_Name'].count()
count_origin.plot(kind='barh',figsize=(10,5),legend=None, title="The Number of Products by Origin ")

# %%
sum_revenue = df.groupby([df['Origin']])['Weekly_Revenue'].sum()
sum_revenue.plot(kind='barh',figsize=(10,5),legend=None, title="The Weekly Revenue by Origin ")

# %%
count_platform = df.groupby(['Platform'])['Product_Name'].count()
count_platform
# Out:
# Platform
# Freshgogo     100
# Weee          300
# Yami         2321
# Name: Product_Name, dtype: int64

# %%
platform = df.groupby([df['Platform']])['Brand'].count()
platform.plot(kind='barh',figsize=(10,5),legend=None, title="The Number of Products by Platform ")

# %%
# Finding the correlation bewteen the Features.
plt.figure(figsize=(8,5))

corr = df.corr()# plot the heatmap
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, 
            annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True))
plt.title('Figure 5: Correlations')
# Out:
# Text(0.5, 1.0, 'Figure 5: Correlations')

# %% [markdown]
# ## Origin vs Platform

# %%
# Origin vs Platform

plt.rcParams['figure.figsize'] = (10, 6)

# compare the year with Origin with Platform
plt.subplot(121)
sns.countplot(x='Platform',hue= 'Origin', data=df, palette = 'husl')
plt.legend(bbox_to_anchor=(-0.2, 0.5), loc='right', borderaxespad=0)
plt.title('Platform vs. Origin')
# Out:
# Text(0.5, 1.0, 'Platform vs. Origin')

# %%
# check the Origin percentage of Platform
plt.rcParams['figure.figsize'] = (15, 5)
ax= plt.subplot(122)
c2_c = pd.crosstab(df.Origin, df.Platform)
c2_c.div(c2_c .sum(1).astype(float), axis=0).plot(kind='barh', stacked=True, ax=ax)
plt.title('Origin percentage by Platform')
plt.legend(bbox_to_anchor=(-0.2, 1), loc='left', borderaxespad=0)
plt.xlabel('Platform')
plt.xticks(rotation=90)
plt.ylabel('Percentage of Origin')

c2_c
# Out:
# C:\Users\13750\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Unrecognized location 'left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   import sys
# Platform        Freshgogo  Weee  Yami
# Origin
# Australia               0     2     1
# Canada                  0     1     0
# England                 0     0     1
# Hong Kong               0     3    19
# India                   0     1     0
# Indonesia               0     1    40
# Japan                   0    21   442
# Korea                   1     0   286
# Mainland China          3   136   965
# Malaysia                0     0    71
# Philippine              0     0    17
# Philippines             0     5     0
# Singapore               0     1    34
# South Korea             0    39     0
# Taiwan                  0    40   307
# Thailand                0     8    26
# Unclear                96     4    39
# United States           0    31    66
# Vietnam                 0     7     7

# %% [markdown]
# ## Origin Vs Sold_Weekly_Group

# %%
df['Sold_Weekly_Group'] = pd.cut(x = df['Sold_Weekly'], 
                                   bins = [0,50,100,200,300,400,500,1000,2000,10000],
                                   labels = ['Less than 50','50+','100+','200+','300+','400+','500+','1000+','2000+'])
df.head()
# Out:
#          Brand Category         Origin Platform  Price  \
# 0  gree noodle   Noodle          Japan     Yami   1.99
# 1  noodle zero   Noodle  United States     Yami   3.99
# 2  noodle soul   Noodle        Vietnam     Yami   3.99
# 3  noodle soul   Noodle        Vietnam     Yami   3.99
# 4  noodle soul   Noodle        Vietnam     Yami   3.99
#
#                        Product_Name Rate  Reviews  Sold_Monthly  Sold_Weekly  \
# 0             GreeNoodle Plain 100g  4.6       41          1600          400
# 1  Tom Yum Flavor Noodle 46Cal 380g  3.6        0          1600          400
# 2     Medium Cut Ramen Noodles 600g    5        1          1600          400
# 3            Knife Cut Noodles 600g    0        0          1600          400
# 4       Thin Cut Ramen Noodles 600g    0        0          1600          400
#
#    Weekly_Revenue Sold_Weekly_Group
# 0             796              300+
# 1            1596              300+
# 2            1596              300+
# 3            1596              300+
# 4            1596              300+

# %%
# origin vs sold weekly group

plt.rcParams['figure.figsize'] = (20, 7)

# compare the year with Origin with Platform
plt.subplot(121)
sns.countplot(x='Sold_Weekly_Group',hue= 'Origin', data=df, palette = 'husl')
plt.legend(bbox_to_anchor=(-0.2, 0.5), loc='right', borderaxespad=0)
plt.title('Sold_Weekly_Group vs. Origin')
# Out:
# Text(0.5, 1.0, 'Sold_Weekly_Group vs. Origin')

# %%
# origin vs sold weekly group

plt.rcParams['figure.figsize'] = (15, 7)
# check the Origin percentage of Platform
ax= plt.subplot(122)
c2_c = pd.crosstab(df.Origin,  df.Sold_Weekly_Group)
c2_c.div(c2_c .sum(1).astype(float), axis=0).plot(kind='barh', stacked=True, ax=ax)
plt.title('Origin percentage by Sold_Weekly_Group')
plt.legend(bbox_to_anchor=(-0.3, 1), loc='left', borderaxespad=0)
plt.xlabel('Sold_Weekly_Group')
plt.xticks(rotation=65)
plt.ylabel('Percentage of Origin')

c2_c
# Out:
# C:\Users\13750\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: MatplotlibDeprecationWarning: Unrecognized location 'left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   if __name__ == '__main__':
# Sold_Weekly_Group  Less than 50  50+  100+  200+  300+  400+  500+  1000+  \
# Origin
# Australia                     0    0     0     0     1     1     1      0
# Canada                        0    0     0     0     0     0     1      0
# England                       0    0     0     0     1     0     0      0
# Hong Kong                     4    0     1     0    17     0     0      0
# India                         0    1     0     0     0     0     0      0
# Indonesia                     0    0     0     0    40     0     1      0
# Japan                         8    4    42    10   390     2     7      0
# Korea                        23    0     7     1   255     0     1      0
# Mainland China               97   20    71    45   810    10    45      2
# Malaysia                      5    0     0     3    63     0     0      0
# Philippine                    0    0     0     0    17     0     0      0
# Philippines                   2    0     1     0     0     0     0      0
# Singapore                     0    2     0     0    33     0     0      0
# South Korea                   7    8     4     7     1     1     2      0
# Taiwan                       19    9     7     9   290     0     8      0
# Thailand                      0    1     2     1    27     1     2      0
# Unclear                       1    0     1     2    41    13    53     23
# United States                 4    3     6     5    67     2     9      0
# Vietnam                       1    0     1     2     7     1     1      0
#
# Sold_Weekly_Group  2000+
# Origin
# Australia              0
# Canada                 0
# England                0
# Hong Kong              0
# India                  0
# Indonesia              0
# Japan                  0
# Korea                  0
# Mainland China         0
# Malaysia               0
# Philippine             0
# Philippines            0
# Singapore              0
# South Korea            0
# Taiwan                 0
# Thailand               0
# Unclear                5
# United States          0
# Vietnam                0

# %% [markdown]
# ## Price_Group Vs Origin

# %%
df['Price_Group'] = pd.cut(x = df['Price'], 
                                   bins = [0,2,4,6,8,10,12,14,16,10000],
                                   labels = ['Less than 2','2+','4+','6+','8+','10+','12+','14+','16+'])
df.head()
# Out:
#          Brand Category         Origin Platform  Price  \
# 0  gree noodle   Noodle          Japan     Yami   1.99
# 1  noodle zero   Noodle  United States     Yami   3.99
# 2  noodle soul   Noodle        Vietnam     Yami   3.99
# 3  noodle soul   Noodle        Vietnam     Yami   3.99
# 4  noodle soul   Noodle        Vietnam     Yami   3.99
#
#                        Product_Name Rate  Reviews  Sold_Monthly  Sold_Weekly  \
# 0             GreeNoodle Plain 100g  4.6       41          1600          400
# 1  Tom Yum Flavor Noodle 46Cal 380g  3.6        0          1600          400
# 2     Medium Cut Ramen Noodles 600g    5        1          1600          400
# 3            Knife Cut Noodles 600g    0        0          1600          400
# 4       Thin Cut Ramen Noodles 600g    0        0          1600          400
#
#    Weekly_Revenue Sold_Weekly_Group  Price_Group
# 0             796              300+  Less than 2
# 1            1596              300+           2+
# 2            1596              300+           2+
# 3            1596              300+           2+
# 4            1596              300+           2+

# %%
# origin vs Price group

plt.rcParams['figure.figsize'] = (20, 6)

# compare the year with Origin with price group
plt.subplot(121)
sns.countplot(x='Origin',hue= 'Price_Group', data=df, palette = 'husl')
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(-0.2, 0.5), loc='right', borderaxespad=0)
plt.title('Price_Group vs. Origin')
# Out:
# Text(0.5, 1.0, 'Price_Group vs. Origin')

# %%
# origin vs sold weekly group

plt.rcParams['figure.figsize'] = (15, 5)

# check the Origin percentage of Platform
ax= plt.subplot(122)
c2_c = pd.crosstab(df.Price_Group, df.Origin)
c2_c.div(c2_c .sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, ax=ax)
plt.title('Origin percentage by Price_Group')
plt.legend(bbox_to_anchor=(-0.2, 1), loc='left', borderaxespad=0)
plt.xlabel('Price_Group')
plt.xticks(rotation=0)
plt.ylabel('Percentage of Origin')

c2_c
# Out:
# C:\Users\13750\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Unrecognized location 'left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   # Remove the CWD from sys.path while we load stuff.
# Origin       Australia  Canada  England  Hong Kong  India  Indonesia  Japan  \
# Price_Group
# Less than 2          0       0        0          4      1         16     97
# 2+                   3       1        0         11      0         17    203
# 4+                   0       0        0          5      0          2     75
# 6+                   0       0        0          2      0          6     40
# 8+                   0       0        0          0      0          0      8
# 10+                  0       0        0          0      0          0      5
# 12+                  0       0        0          0      0          0      4
# 14+                  0       0        0          0      0          0     15
# 16+                  0       0        1          0      0          0     16
#
# Origin       Korea  Mainland China  Malaysia  Philippine  Philippines  \
# Price_Group
# Less than 2    101             253         1           4            1
# 2+              83             470        20           1            3
# 4+              57             241        27           9            1
# 6+              30              77        20           3            0
# 8+              13              18         0           0            0
# 10+              0              18         1           0            0
# 12+              0               4         1           0            0
# 14+              1               0         1           0            0
# 16+              2              23         0           0            0
#
# Origin       Singapore  South Korea  Taiwan  Thailand  Unclear  United States  \
# Price_Group
# Less than 2          7            8      81        15       12              5
# 2+                   5           10     103        13       25             40
# 4+                   4           10      57         2       13             29
# 6+                   2            9      51         2        6              8
# 8+                   9            2      25         0       20              2
# 10+                  3            0      13         0       16              1
# 12+                  0            0       6         2       21              1
# 14+                  1            0       4         0       11              1
# 16+                  4            0       7         0       15             10
#
# Origin       Vietnam
# Price_Group
# Less than 2        5
# 2+                 7
# 4+                 2
# 6+                 0
# 8+                 0
# 10+                0
# 12+                0
# 14+                0
# 16+                0

# %% [markdown]
# ## Price_Group Vs Sold_Weekly_Group

# %%
plt.rcParams['figure.figsize'] = (20, 5)

# check the Price_Group percentage of Sold_Weekly_Group
ax= plt.subplot(122)
c2_c = pd.crosstab(df.Price_Group, df.Sold_Weekly_Group)
c2_c.div(c2_c .sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, ax=ax)
plt.title('Sold_Weekly_Group percentage by Price_Group')
plt.legend(bbox_to_anchor=(-0.1, 1), loc='left', borderaxespad=0)
plt.xlabel('Price_Group')
plt.xticks(rotation=0)
plt.ylabel('Percentage of Sold_Weekly_Group')

c2_c
# Out:
# C:\Users\13750\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Unrecognized location 'left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
# Sold_Weekly_Group  Less than 50  50+  100+  200+  300+  400+  500+  1000+  \
# Price_Group
# Less than 2                  43    7    26    24   491     3    14      0
# 2+                           52   11    41    33   835     6    27      2
# 4+                           40   13    26    12   385     8    37      6
# 6+                           22    8    18     9   182     2     7      3
# 8+                            5    3     3     2    65     3     8      7
# 10+                           3    4     3     1    30     1     8      5
# 12+                           1    2     2     0    14     4    14      1
# 14+                           1    0    10     3    10     1     8      1
# 16+                           4    0    14     1    48     3     8      0
#
# Sold_Weekly_Group  2000+
# Price_Group
# Less than 2            0
# 2+                     1
# 4+                     1
# 6+                     0
# 8+                     1
# 10+                    2
# 12+                    0
# 14+                    0
# 16+                    0

# %%
# price group vs sold weekly group

plt.rcParams['figure.figsize'] = (20, 4)

# compare the year with price group with sold weekly group
plt.subplot(121)
sns.countplot(x='Price_Group',hue= 'Sold_Weekly_Group', data=df, palette = 'husl')
plt.legend(bbox_to_anchor=(-0.2, 0.5), loc='right', borderaxespad=0)
plt.title('Price_Group vs. Sold_Weekly_Group')
# Out:
# Text(0.5, 1.0, 'Price_Group vs. Sold_Weekly_Group')

# %%
df.to_csv(r'C:\Users\13750\Desktop\Empire Bazaar Group Corp\US chinese product market\SNACK MARKET\Analysis Data\noodle\noodle.csv', index = False)
